# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import scipy
import pandas as pd

# %%
mu = 1.5
sigma = 0.2
alpha = 0.05

# %%
data = pd.read_csv("dane1.txt",header = None,names=["a"])

# %%
n = len(data)

# %%
Z = (data["a"].mean()-mu)*np.sqrt(n)/sigma
Z
# Out:
# -7.041450899607125

# %% [markdown]
# $ \mu \ne 1.5$

# %% [markdown]
# ### przedział krytyczny

# %%
row = 1-alpha/2
quantile = scipy.stats.norm.ppf(row,0,1)
quantile
# Out:
# 1.959963984540054

# %% [markdown]
# $ C = (- \infty, -1.891993] \hspace{5mm}\bigcup \hspace{5mm} [1.891993,\infty) $

# %% [markdown]
# ### p-wartość

# %%
p_value1 = 2- 2 * scipy.stats.norm.cdf(abs(Z))
p_value1
# Out:
# 1.9024781749976682e-12

# %%
x = np.arange(-9,9,0.01)
y = [scipy.stats.norm.pdf(i,0,1) for i in x]

plt.figure(figsize=(8, 5))

plot_1 = sns.lineplot(x,y,label="Gęstość rozkładu N(0,1)")

plot_1.fill_between(x,0,y, where = (x>quantile), color = "r", label="Obszar krytyczny")
plot_1.fill_between(x,0,y, where = (x<-quantile), color = "r")

plt.axvline(x=-7.0415, linestyle="dashed", label = "Statystyka testowa Z",color = "darkgreen")
plt.annotate(text = "Z = -7.041",xy=(-6.5,0.15),color = "darkgreen",fontsize=12)
plt.xlabel("x")
plt.ylabel("Gęstość rozkładu N(0,1)")
plt.legend()
plt.grid()
plt.savefig("Zad1_1_05.pdf")
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# $ \mu > 1.5$

# %%
row2= 1-alpha
quantile2 = scipy.stats.norm.ppf(row2,0,1)
quantile2
# Out:
# 1.6448536269514722

# %%
x = np.arange(-9,9,0.01)
y = [scipy.stats.norm.pdf(i,0,1) for i in x]

plt.figure(figsize=(8, 5))

plot_1 = sns.lineplot(x,y,label="Gęstość rozkładu N(0,1)")

plot_1.fill_between(x,0,y, where = (x>quantile2), color = "r", label="Obszar krytyczny")

plt.axvline(x=-7.0415, linestyle="dashed", label = "Statystyka testowa Z",color = "darkgreen")
plt.annotate(text = "Z = -7.041",xy=(-6.5,0.15),color = "darkgreen",fontsize=12)

plt.xlabel("x")
plt.ylabel("Gęstość rozkładu N(0,1)")
plt.legend()
plt.grid()
plt.savefig("Zad1_2_05.pdf")
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# $ (1.8289707253902945, \infty) $

# %% [markdown]
# ### p-wartość

# %%
p_value2 = 1 - scipy.stats.norm.cdf(Z)
p_value2
# Out:
# 0.9999999999990488

# %% [markdown]
# $ \mu <1.5$

# %% [markdown]
# $ (- \infty, -1.8289707253902945 )$

# %% [markdown]
# ### p-wartość

# %%
p_value3 = scipy.stats.norm.cdf(Z)
p_value3
# Out:
# 9.512412912411132e-13

# %%
x = np.arange(-9,9,0.01)
y = [scipy.stats.norm.pdf(i,0,1) for i in x]

plt.figure(figsize=(8, 5))

plot_1 = sns.lineplot(x,y,label="Gęstość rozkładu N(0,1)")

plot_1.fill_between(x,0,y, where = (x<-quantile2), color = "r",label="Obszar krytyczny")

plt.axvline(x=-7.0415, linestyle="dashed", label = "Statystyka testowa Z",color = "darkgreen")
plt.annotate(text = "Z = -7.041",xy=(-6.5,0.15),color = "darkgreen",fontsize=12)

plt.xlabel("x")
plt.ylabel("Gęstość rozkładu N(0,1)")
plt.legend()
plt.grid()
plt.savefig("Zad1_3_05.pdf")
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
alpha2 = 0.01
alpha3 = 0.1

# %% [markdown]
# # alpha = 0.01

# %% [markdown]
# $ \mu \ne 1.5$

# %%
row1_a2 = 1-alpha2/2
quantile1_a2 = scipy.stats.norm.ppf(row1_a2,0,1)
quantile1_a2
# Out:
# 2.5758293035489004

# %%
p_value1_a2 = 2 - 2 * scipy.stats.norm.cdf(abs(Z))
p_value1_a2
# Out:
# 1.9024781749976682e-12

# %% [markdown]
# $ \mu > 1.5$

# %%
row2_a2= 1-alpha2
quantile2_a2 = scipy.stats.norm.ppf(row2_a2,0,1)
quantile2_a2
# Out:
# 2.3263478740408408

# %%
p_value2_a2 = 1 - scipy.stats.norm.cdf(Z)
p_value2_a2
# Out:
# 0.9999999999990488

# %% [markdown]
# $ \mu < 1.5$

# %%
p_value3_a2 = scipy.stats.norm.cdf(Z)
p_value3_a2
# Out:
# 9.512412912411132e-13

# %% [markdown]
# # alpha =0.1

# %%
row1_a3 = 1-alpha3/2
quantile1_a3 = scipy.stats.norm.ppf(row1_a3,0,1)
quantile1_a3
# Out:
# 1.6448536269514722

# %%
p_value1_a3 = 2 - 2 * scipy.stats.norm.cdf(abs(Z))
p_value1_a3
# Out:
# 1.9024781749976682e-12

# %%
row2_a3= 1-alpha3
quantile2_a3 = scipy.stats.norm.ppf(row2_a3,0,1)
quantile2_a3
# Out:
# 1.2815515655446004

# %%
p_value2_a3 = 1 - scipy.stats.norm.cdf(Z)
p_value2_a3
# Out:
# 0.9999999999990488

# %%
p_value3_a3 = scipy.stats.norm.cdf(Z)
p_value3_a3
# Out:
# 9.512412912411132e-13

# %% [markdown]
# # błąd I rodzaju

# %% [markdown]
# ### dla $\mu$

# %%
def test_1(alpha,hipo):
    k = 1000
    sigma=0.2
    mu = 1.5
    N=1000
    if hipo == "ne":
        row = 1-alpha/2
        quantile = scipy.stats.norm.ppf(row,0,1)
        X_vector = scipy.stats.norm.rvs(mu,sigma,(N,k))
        Z_test = (np.mean(X_vector,axis=1)-mu)/sigma*np.sqrt(k)
        answer=  (Z_test <= -quantile) + (Z_test >= quantile)
        return np.mean(answer)
    if hipo == "gt":
        row = 1-alpha
        quantile = scipy.stats.norm.ppf(row,0,1)
        X_vector = scipy.stats.norm.rvs(mu,sigma,(N,k))
        Z_test = (np.mean(X_vector,axis=1)-mu)/sigma*np.sqrt(k)
        answer= (Z_test >= quantile)
        return np.mean(answer)
    if hipo == "lt":
        row = 1-alpha
        quantile = scipy.stats.norm.ppf(row,0,1)
        X_vector = scipy.stats.norm.rvs(mu,sigma,(N,k))
        Z_test = (np.mean(X_vector,axis=1)-mu)/sigma*np.sqrt(k)
        answer= (Z_test <= -quantile)
        return np.mean(answer)

# %%
M=100
repeat_mu_ne = [test_1(0.05,"ne") for i in range(M)]

# %%
repeat_mu_gt = [test_1(0.05,"gt")for i in range(M)]

# %%
repeat_mu_lt = [test_1(0.05,"lt")for i in range(M)]

# %%
plt.boxplot(repeat_mu_ne)
plt.ylabel("Błąd I rodzaju")
plt.title("Błąd I rodzaju,  µ != 1.5, α = 0.05")
plt.show()

# %%
plt.boxplot(repeat_mu_gt)
plt.ylabel("Błąd I rodzaju")
plt.title("Błąd I rodzaju,  µ > 1.5, α = 0.05")
plt.show()

# %%
plt.boxplot(repeat_mu_lt)
plt.ylabel("Błąd I rodzaju")
plt.title("Błąd I rodzaju,  µ < 1.5, α = 0.05")
plt.show()

# %%
def test_2(alpha,hipo):
    k = 1000
    mu = 1.5
    sigma=0.2
    zero_hipo = 1.5
    N=1000
    freedom = k-1
    if hipo == "ne":
        row_down = alpha/2
        row_up = 1-alpha/2
        quantile_down = scipy.stats.chi2.ppf(row_down,freedom)
        quantile_up = scipy.stats.chi2.ppf(row_up,freedom)
        X_vector = scipy.stats.norm.rvs(mu,sigma,(N,k))
        Chi_test = np.var(X_vector,axis=1)*freedom/sigma**2
        answer =  (Chi_test <= quantile_down) + (Chi_test >= quantile_up)
        return np.mean(answer)
    if hipo == "gt":
        row = 1-alpha
        quantile = scipy.stats.chi2.ppf(row,freedom)
        X_vector = scipy.stats.norm.rvs(mu,sigma,(N,k))
        Chi_test = np.var(X_vector,axis=1)*freedom/sigma**2
        answer = (Chi_test >= quantile)
        return np.mean(answer)
    if hipo == "lt":
        row = alpha
        quantile = scipy.stats.chi2.ppf(row,freedom)
        X_vector = scipy.stats.norm.rvs(mu,sigma,(N,k))
        Chi_test = np.var(X_vector,axis=1)*freedom/sigma**2
        answer = (Chi_test <= quantile)
    return np.mean(answer)

# %%
repeat_sigma_ne = [test_2(0.05,"ne") for i in range(M)]

# %%
repeat_sigma_gt = [test_2(0.05,"gt") for i in range(M)]

# %%
repeat_sigma_lt = [test_2(0.05,"lt") for i in range(M)]

# %%
plt.boxplot(repeat_sigma_ne)
plt.ylabel("Błąd I rodzaju")
plt.title("Błąd I rodzaju,  σ^2 != 1.5, α = 0.05")
plt.show()

# %%
plt.boxplot(repeat_sigma_gt)
plt.xlabel("Błąd I rodzaju")
plt.title("Błąd I rodzaju,  σ^2 > 1.5, α = 0.05")
plt.show()

# %%
plt.boxplot(repeat_sigma_lt)
plt.xlabel("Błąd I rodzaju")
plt.title("Błąd I rodzaju,  σ^2 < 1.5, α = 0.05")
plt.show()
